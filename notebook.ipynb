# %% [markdown]
# Sometimes it's easier to test a library without the UI/server.

# %%
import server
from importlib import reload
reload(server)
# Test libraries here.
# Out:
# <module 'server' from '/Users/emilyreif/Documents/github/ts_py_server/server.py'>
